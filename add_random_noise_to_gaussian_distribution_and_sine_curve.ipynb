# %%
import numpy
numpy.__version__
# Out:
# '1.24.3'

# %%
# 1. Generate 1000 points randomly using Normal/Gaussian distribution

# 2. plot the random points.

# 3. add random noise to the 1000 points

# 4. plot the points (After addition of the noise)

import numpy as np

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
print(s)
# Out:
# [ 8.06181402e-02  1.17047396e-01  4.07912033e-02  9.40963797e-02
#  -4.53088389e-02  4.12486534e-03  2.31781281e-01 -1.13863502e-01
#   2.49308132e-01  7.57123626e-02 -2.86230760e-02  7.41575627e-02
#  -1.72837644e-02  7.73574436e-03  8.47700614e-02 -4.98216400e-02
#   2.83589974e-02 -1.40728452e-02  1.97568709e-01  9.87501630e-02
#   4.24864902e-03 -1.64513842e-02 -5.63277391e-02  1.47519134e-01
#   1.80927558e-01  6.06322188e-02 -6.25227830e-03 -1.97293358e-01
#   3.07276847e-02  2.10290553e-02 -4.18556186e-02  5.80528102e-02
#   2.04615505e-02 -1.07438126e-02  1.26770260e-01  6.08088734e-02
#  -7.19938152e-02  2.31828756e-02 -3.19410382e-02 -8.56689398e-02
#  -1.06608081e-01 -9.47136128e-03 -5.08011476e-02 -9.36068525e-02
#   6.12655824e-03 -3.36243075e-02  7.33111289e-02  8.96400363e-02
#   5.78724719e-02  2.95483005e-02  7.77235918e-02 -1.82022474e-01
#  -1.50520853e-01  7.51172669e-03  2.57738159e-02  9.28876892e-02
# ...

# %%
np.random.uniform(0, 1)
# Out:
# 0.34180587739875

# %%
MAX = 1000
noise = []
for i in range(MAX):
    noise.append(np.random.uniform(0, 0.5))
    
print(noise)
# Out:
# [0.19281013034578648, 0.03369548601075856, 0.11563713437563944, 0.40015008937677565, 0.36515174258075267, 0.3298312584320611, 0.4224520324927441, 0.08656824377539185, 0.393843338923182, 0.2293303840780545, 0.273445538667168, 0.35413040264420187, 0.053648521825853, 0.23466115185748887, 0.035898977363425844, 0.29787710562496633, 0.4883973639247131, 0.15619556472825563, 0.16179887728065678, 0.40006805720216315, 0.18659044818457382, 0.4745247940433133, 0.09670264332742673, 0.3435584439439333, 0.24547490835271396, 0.30962007625442595, 0.04524176903634253, 0.30295069225441607, 0.06556617305615237, 0.1937118537162122, 0.24158600248273737, 0.3583589392993225, 0.39798228288970156, 0.16983879859025347, 0.3060557184025863, 0.2629757323969308, 0.06815488197474023, 0.0015938769115992346, 0.2517106104885051, 0.4623308536721757, 0.14431727596119892, 0.060072738489786726, 0.47137194484572437, 0.1587415500103898, 0.10935249912533351, 0.008117812810390368, 0.03707696647226605, 0.48788324745608297, 0.4
# ...

# %%
len(noise)
# Out:
# 1000

# %%
new_s = s + noise

# %%
import matplotlib.pyplot as plt

plt.hist(s, bins = 20)
# A histogram is an approximate representation of the distribution of numerical data. 
#To construct a histogram, the first step is to "bin" (or "bucket") the range of 
# values—that is, divide the entire range of values into a series of intervals—and then count how many values fall into each interval. The bins are usually specified as consecutive, non-overlapping intervals of a variable
# Out:
# (array([  3.,   3.,   4.,  22.,  30.,  59.,  74.,  96., 122., 138., 136.,
#         118.,  78.,  51.,  37.,  14.,  10.,   2.,   1.,   2.]),
#  array([-0.33086252, -0.29647237, -0.26208222, -0.22769207, -0.19330192,
#         -0.15891178, -0.12452163, -0.09013148, -0.05574133, -0.02135118,
#          0.01303897,  0.04742912,  0.08181927,  0.11620941,  0.15059956,
#          0.18498971,  0.21937986,  0.25377001,  0.28816016,  0.32255031,
#          0.35694046]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(new_s, bins = 20)
# Out:
# (array([  1.,   0.,   4.,   9.,  25.,  46.,  65.,  90.,  95., 105.,  92.,
#         102., 111.,  77.,  73.,  61.,  27.,  10.,   4.,   3.]),
#  array([-0.31590553, -0.26169857, -0.2074916 , -0.15328464, -0.09907767,
#         -0.04487071,  0.00933626,  0.06354322,  0.11775019,  0.17195715,
#          0.22616412,  0.28037108,  0.33457805,  0.38878501,  0.44299198,
#          0.49719894,  0.55140591,  0.60561287,  0.65981984,  0.7140268 ,
#          0.76823377]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(noise, bins = 20)
# Out:
# (array([60., 57., 62., 44., 48., 47., 47., 64., 53., 53., 56., 38., 49.,
#         45., 47., 47., 41., 44., 56., 42.]),
#  array([0.00159388, 0.02649314, 0.05139241, 0.07629168, 0.10119094,
#         0.12609021, 0.15098948, 0.17588874, 0.20078801, 0.22568728,
#         0.25058655, 0.27548581, 0.30038508, 0.32528435, 0.35018361,
#         0.37508288, 0.39998215, 0.42488141, 0.44978068, 0.47467995,
#         0.49957921]),
#  <BarContainer object of 20 artists>)

# %%
x_vals = list(range(1000))

# %%
plt.plot(x_vals, s)

# %%
plt.plot(x_vals, noise)

# %%
# numpy linspace Return evenly spaced numbers over a specified interval.
x = np.linspace(-10, 10, 1000)
y = np.sin(x)
plt.plot(x, y)

# %%
y
# Out:
# array([ 0.54402111,  0.52711499,  0.5099976 ,  0.49267581,  0.47515657,
#         0.45744688,  0.43955386,  0.42148467,  0.40324656,  0.38484682,
#         0.36629285,  0.34759207,  0.32875198,  0.30978013,  0.29068412,
#         0.27147162,  0.2521503 ,  0.23272793,  0.21321229,  0.19361119,
#         0.1739325 ,  0.15418409,  0.13437389,  0.11450984,  0.09459989,
#         0.07465203,  0.05467424,  0.03467455,  0.01466095, -0.00535852,
#        -0.02537584, -0.04538299, -0.06537195, -0.08533471, -0.10526327,
#        -0.12514965, -0.14498586, -0.16476397, -0.18447604, -0.20411417,
#        -0.2236705 , -0.24313718, -0.26250642, -0.28177045, -0.30092154,
#        -0.31995204, -0.3388543 , -0.35762075, -0.37624387, -0.39471619,
#        -0.41303032, -0.43117891, -0.44915469, -0.46695046, -0.48455907,
#        -0.50197348, -0.51918671, -0.53619185, -0.5529821 , -0.56955071,
#        -0.58589106, -0.60199658, -0.61786084, -0.63347746, -0.6488402 ,
# ...

# %%
y_new = y + noise
plt.plot(x, y_new)
